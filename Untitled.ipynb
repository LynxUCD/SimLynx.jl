# %%
include("event_based.jl")
# Out:
#                    _____ _           _                        _ _
#   `\.      ,/'    /  ___(_)         | |                      (_) |
#    |\\____//|     \ `--. _ _ __ ___ | |    _   _ _ __ __  __  _| |
#    )/_ `' _\(      `--. \ | '_ ` _ \| |   | | | | '_ \\ \/ / | | |
#   ,'/-`__'-\`\    /\__/ / | | | | | | |___| |_| | | | |>  < _| | |
#   /. (_><_) ,\    \____/|_|_| |_| |_\_____/\__, |_| |_/_/\_(_) |_|
#   '`)/`--'\(`'                              __/ |           _/ |
#     '      '                               |___/           |__/
#
# A Hybrid Simulation Engine and Language in Julia
# SimLynx.jl Version 0.3.0 2020-10-08
# University of Colorado in Denver
# Dr. Doug Williams, Anthony Dupont, Trystan Kaes
#
# 0.0: Customer(1) arrives
# 0.0: Teller(1) starts servicing Customer(1)
# 0.21711206707586023: Customer(2) arrives
# 0.21711206707586023: Teller(2) starts servicing Customer(2)
# 3.513096807655826: Teller(2) finishes servicing Customer(2)
# ...

# %%
include("example-1.jl")
# Out:
#                    _____ _           _                        _ _
#   `\.      ,/'    /  ___(_)         | |                      (_) |
#    |\\____//|     \ `--. _ _ __ ___ | |    _   _ _ __ __  __  _| |
#    )/_ `' _\(      `--. \ | '_ ` _ \| |   | | | | '_ \\ \/ / | | |
#   ,'/-`__'-\`\    /\__/ / | | | | | | |___| |_| | | | |>  < _| | |
#   /. (_><_) ,\    \____/|_|_| |_| |_\_____/\__, |_| |_/_/\_(_) |_|
#   '`)/`--'\(`'                              __/ |           _/ |
#     '      '                               |___/           |__/
#
# A Hybrid Simulation Engine and Language in Julia
# SimLynx.jl Version 0.3.0 2020-10-08
# University of Colorado in Denver
# Dr. Doug Williams, Anthony Dupont, Trystan Kaes
# Statistics
#      min = 0
#      max = 2
#        n = 393.6522304016719
#     mean = 1.5663395853435238
# variance = 0.39547733584948164
#   stddev = 0.6288698878539833
# Statistics
#      min = 0
#      max = 7
#        n = 393.6522304016719
#     mean = 0.9138038605399105
# ...

# %%
include("example-5.jl")
# Out:
#                    _____ _           _                        _ _
#   `\.      ,/'    /  ___(_)         | |                      (_) |
#    |\\____//|     \ `--. _ _ __ ___ | |    _   _ _ __ __  __  _| |
#    )/_ `' _\(      `--. \ | '_ ` _ \| |   | | | | '_ \\ \/ / | | |
#   ,'/-`__'-\`\    /\__/ / | | | | | | |___| |_| | | | |>  < _| | |
#   /. (_><_) ,\    \____/|_|_| |_| |_\_____/\__, |_| |_/_/\_(_) |_|
#   '`)/`--'\(`'                              __/ |           _/ |
#     '      '                               |___/           |__/
#
# A Hybrid Simulation Engine and Language in Julia
# SimLynx.jl Version 0.3.0 2020-10-08
# University of Colorado in Denver
# Dr. Doug Williams, Anthony Dupont, Trystan Kaes
# Statistics
#      min = 6
#      max = 12
#        n = 10000
#     mean = 7.5318
# variance = 0.6821887600000096
#   stddev = 0.8259471895950792
# Writing History plot to file "max_tellers.png"
# 118.856288 seconds (374.03 M allocations: 37.913 GiB, 3.57% gc time)

# %%
include("tally-and-accumulate.jl")
# Out:
#                    _____ _           _                        _ _
#   `\.      ,/'    /  ___(_)         | |                      (_) |
#    |\\____//|     \ `--. _ _ __ ___ | |    _   _ _ __ __  __  _| |
#    )/_ `' _\(      `--. \ | '_ ` _ \| |   | | | | '_ \\ \/ / | | |
#   ,'/-`__'-\`\    /\__/ / | | | | | | |___| |_| | | | |>  < _| | |
#   /. (_><_) ,\    \____/|_|_| |_| |_\_____/\__, |_| |_/_/\_(_) |_|
#   '`)/`--'\(`'                              __/ |           _/ |
#     '      '                               |___/           |__/
#
# A Hybrid Simulation Engine and Language in Julia
# SimLynx.jl Version 0.3.0 2020-10-08
# University of Colorado in Denver
# Dr. Doug Williams, Anthony Dupont, Trystan Kaes
# --- Test Tally and Accumulate ---
# --- Tally ---
# N    = 4
# Sum  = 10.0
# Mean = 2.5
# Writing Tallied History plot to file "tallied.png"
# --- Accumulate ---
# N    = 8.0
# Sum  = 22.0
# Mean = 2.75
# Writing Accumulated History plot to file "accumulated.png"

# %%
include("event_based.jl")
# Out:
#                    _____ _           _                        _ _
#   `\.      ,/'    /  ___(_)         | |                      (_) |
#    |\\____//|     \ `--. _ _ __ ___ | |    _   _ _ __ __  __  _| |
#    )/_ `' _\(      `--. \ | '_ ` _ \| |   | | | | '_ \\ \/ / | | |
#   ,'/-`__'-\`\    /\__/ / | | | | | | |___| |_| | | | |>  < _| | |
#   /. (_><_) ,\    \____/|_|_| |_| |_\_____/\__, |_| |_/_/\_(_) |_|
#   '`)/`--'\(`'                              __/ |           _/ |
#     '      '                               |___/           |__/
#
# A Hybrid Simulation Engine and Language in Julia
# SimLynx.jl Version 0.3.0 2020-10-08
# University of Colorado in Denver
# Dr. Doug Williams, Anthony Dupont, Trystan Kaes
#
# 0.0: Customer(1) arrives
# 0.0: Teller(1) starts servicing Customer(1)
# 6.687820799884452: Teller(1) finishes servicing Customer(1)
# 7.135403511355542: Customer(2) arrives
# 7.135403511355542: Teller(1) starts servicing Customer(2)
# ...
