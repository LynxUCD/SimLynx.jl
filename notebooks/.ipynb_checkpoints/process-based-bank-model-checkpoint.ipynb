# %% [markdown]
# # SimLynx.jl Process-Based Discrete-Event Simulation Example
# This is a simple process-based discrete-event simulation of an N teller, single queue bank using the SimLynx.jl hybrid simulation engine and language in Julia.

# %%
using SimLynx
SimLynx.greet()
# Out:
#                    _____ _           _                        _ _
#   `\.      ,/'    /  ___(_)         | |                      (_) |
#    |\\____//|     \ `--. _ _ __ ___ | |    _   _ _ __ __  __  _| |
#    )/_ `' _\(      `--. \ | '_ ` _ \| |   | | | | '_ \\ \/ / | | |
#   ,'/-`__'-\`\    /\__/ / | | | | | | |___| |_| | | | |>  < _| | |
#   /. (_><_) ,\    \____/|_|_| |_| |_\_____/\__, |_| |_/_/\_(_) |_|
#   '`)/`--'\(`'                              __/ |           _/ |
#     '      '                               |___/           |__/
#
# A Hybrid Simulation Engine and Language in Julia
# SimLynx.jl Version 0.4.1 2020-12-11
# University of Colorado in Denver
# Dr. Doug Williams, Anthony Dupont, Trystan Kaes

# %% [markdown]
# This model requires exponential and uniform random distributions, which are in the Distributions package. The Random package is also required to sample these distributions.

# %%
using Distributions: Exponential, Uniform
using Random

# %% [markdown]
# ## Model Parameters
#
# The model has several parameters that can be set to customize the model for specific analyses. These are:
#
# * Number of tellers (N_TELLERS)
# * Mean customer inter-arrival time (MEAN_INTERARRIVAL_TIME)
# * Minimum customer service time (MIN_SERVICE_TIME)
# * Maximum customer service time (MAX_SERVICE_TIME)

# %%
const N_TELLERS = 2
const MEAN_INTERARRIVAL_TIME = 4.0
const MIN_SERVICE_TIME = 2.0
const MAX_SERVICE_TIME = 10.0
# Out:
# 10.0

# %% [markdown]
# ## Passive Elements
#
# The model also has a global variable, tellers, whose value will be set to the resource object representing the bank tellers. This is set to ``nothing`` here and initialized to the appropriate resource object in the main program.

# %%
tellers = nothing

# %% [markdown]
# ## Active Elements (Processes)
#
# The ``generator(n::Integer)`` process generates ``n`` customers arriving into the system with an exponentially distributed inter-arrival time of ``MEAN_INTERARRIVAL_TIME`` minutes.

# %%
"Process to generate n customers arriving into the system."
@process generator(n::Integer) begin
    dist = Exponential(MEAN_INTERARRIVAL_TIME)
    for i = 1:n
        work(rand(dist))
        @schedule now customer(i)
    end
end
# Out:
# generator

# %% [markdown]
# The ``customer(i::Integer)`` process represents the ``i``th customer in the system. Each customer acquires a teller and then works a uniformly distributed time between ``MIN_SERVICE_TIME`` and ``MAX_SERVICE_TIME`` minutes to conduct their bank transaction. The customer then releases the teller and exits the system. Note that requesting (and acquiring) and releasing the teller is done using the ``@with_resource`` macro.

# %%
"The ith customer into the system."
@process customer(i::Integer) begin
    dist = Uniform(MIN_SERVICE_TIME, MAX_SERVICE_TIME)
    @with_resource tellers begin
        work(rand(dist))
    end
end
# Out:
# customer

# %% [markdown]
# ## Main Program
#
# The function ``run_simulation(n::Integer)`` runs the N Teller, Single Queue Bank Model with ``n`` customers. The function first prints a welcome message describing the model and its parameters. It then creates a new simulation to execute the model using the ``@with_new_simulation`` macro. The model itself create the tellers resource with ``N_TELLERS``, schedules the customer generator process (``generator(n::Integer)``) to begin execution at time ``0.0``, and starts the simulation.
#
# When the simulation finishes execution, it will print the results of the simulation. These results are:
#
# * Teller Allocation Statistics
# * Teller Queue Length Statistics
# * Teller Queue Length History
# * Teller Queue Wait Time Statistics
# * Teller Queue Wait Time History
#
# Note that these results were automaticalled collected by SimLynx.

# %%
"Run the simulation for n customers."
function run_simulation(n::Integer)
    println("SimLynx.jl Process-Based Discrete-Event Simulation Example")
    println("$N_TELLERS Teller, Single Queue Bank Model")
    println("  Inter-arrival time = Exponential($MEAN_INTERARRIVAL_TIME)")
    println("  Service time = Uniform($MIN_SERVICE_TIME, $MAX_SERVICE_TIME)")
    println("  Number of customers = $n")
    @simulation begin
        global tellers = Resource(N_TELLERS, "tellers")
        @schedule at 0.0 generator(n)
        start_simulation()
        println("--- Simulation results after $(current_time()) minutes ---")
        print_stats(tellers.allocated, title="Teller Allocation Statistics")
        print_stats(tellers.queue_length, title="Teller Queue Length Statistics")
        plot_history(tellers.queue_length, title="Teller Queue Length History")
        print_stats(tellers.wait, title="Teller Queue Wait Time Statistics")
        plot_history(tellers.wait, title="Teller Queue Wait Time History")
    end
end
# Out:
# run_simulation

# %% [markdown]
# ## Output
#
# We then call the ``run_simulation(n::Integer)`` function with the number of customer to process, ``n``, as its single parameter. This will run the simulation and display the results.

# %%
run_simulation(100)
# Out:
# SimLynx.jl Process-Based Discrete-Event Simulation Example
# 2 Teller, Single Queue Bank Model
#   Inter-arrival time = Exponential(4.0)
#   Service time = Uniform(2.0, 10.0)
#   Number of customers = 100
# --- Simulation results after 422.86184287179924 minutes ---
# Teller Allocation Statistics
#      min = 0
#      max = 2
#        n = 422.86184287179924
#     mean = 1.3754330509145356
# variance = 0.6865408372326169
#   stddev = 0.828577598799664
# Teller Queue Length Statistics
#      min = 0
#      max = 6
#        n = 422.86184287179924
#     mean = 0.8934847445902369
# variance = 1.9846672224314965
#   stddev = 1.4087821770704996
# Displaying Teller Queue Length History plot
# Teller Queue Wait Time Statistics
#      min = 0.0
#      max = 19.493381745531508
#        n = 422.86184287179924
#     mean = 2.985868032087598
# variance = 18.98675645639139
#   stddev = 4.3573795400895925
# Displaying Teller Queue Wait Time History plot
